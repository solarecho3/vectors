# %%
import numpy

# %%
# shape, size
numpy.random.weibull(1,1)[0]
# Out:
# 2.4407617102833137

# %%
import math
1 * math.gamma(1 + 1 / 1)
# Out:
# 1.0

# %%
import numpy
l1 = []
for i in range(9999):
    a = numpy.random.exponential(1.0, size=None)
    a /= 10
    l1.append(a)
    l1.sort()
print(l1[len(l1)-1])
# Out:
# 1.1605587977382357
